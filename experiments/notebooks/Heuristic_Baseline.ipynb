# %% [markdown]
# # Heuristic Baseline
#
# Now that we've done a little bit of EDA. What we need to do now is establish some sort of baseline for the heuristic we're going to choose and also define what metrics we're going to use to measure it. Because
#
# ## Loading in the Data and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import roc_auc_score, roc_curve, auc, brier_score_loss

# %%
race_df = pd.read_csv("../data/races.csv", na_values="\\N", parse_dates=["date", "quali_date"])
race_df.head()
# Out:
#    raceId  year  round  circuitId                   name       date      time  \
# 0       1  2009      1          1  Australian Grand Prix 2009-03-29  06:00:00
# 1       2  2009      2          2   Malaysian Grand Prix 2009-04-05  09:00:00
# 2       3  2009      3         17     Chinese Grand Prix 2009-04-19  07:00:00
# 3       4  2009      4          3     Bahrain Grand Prix 2009-04-26  12:00:00
# 4       5  2009      5          4     Spanish Grand Prix 2009-05-10  12:00:00
#
#                                                  url fp1_date fp1_time  \
# 0  http://en.wikipedia.org/wiki/2009_Australian_G...      NaN      NaN
# 1  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...      NaN      NaN
# 2  http://en.wikipedia.org/wiki/2009_Chinese_Gran...      NaN      NaN
# 3  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...      NaN      NaN
# 4  http://en.wikipedia.org/wiki/2009_Spanish_Gran...      NaN      NaN
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 0      NaN      NaN      NaN      NaN        NaT        NaN         NaN
# 1      NaN      NaN      NaN      NaN        NaT        NaN         NaN
# 2      NaN      NaN      NaN      NaN        NaT        NaN         NaN
# 3      NaN      NaN      NaN      NaN        NaT        NaN         NaN
# 4      NaN      NaN      NaN      NaN        NaT        NaN         NaN
#
#   sprint_time
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
quali_df = pd.read_csv("../data/qualifying.csv", na_values="\\N")
quali_df.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
res_df = pd.read_csv("../data/results.csv", na_values="\\N")
res_df.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0   1.0       1.0
# 1         2      18         2              2     3.0   5.0       2.0
# 2         3      18         3              3     7.0   7.0       3.0
# 3         4      18         4              4     5.0  11.0       4.0
# 4         5      18         5              1    23.0   3.0       5.0
#
#   positionText  positionOrder  points  laps         time  milliseconds  \
# 0            1              1    10.0    58  1:34:50.616     5690616.0
# 1            2              2     8.0    58       +5.478     5696094.0
# 2            3              3     6.0    58       +8.163     5698779.0
# 3            4              4     5.0    58      +17.181     5707797.0
# 4            5              5     4.0    58      +18.014     5708630.0
#
#    fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 0        39.0   2.0       1:27.452          218.300         1
# 1        41.0   3.0       1:27.739          217.586         1
# 2        41.0   5.0       1:28.090          216.719         1
# 3        58.0   7.0       1:28.603          215.464         1
# 4        43.0   1.0       1:27.418          218.385         1

# %%
constructor_df = pd.read_csv("../data/constructors.csv")
constructor_df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
drivers_df = pd.read_csv("../data/drivers.csv", na_values="\\N", parse_dates=["dob"])
drivers_df.head()
# Out:
#    driverId   driverRef  number code  forename     surname        dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton 1985-01-07
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld 1977-05-10
# 2         3     rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 3         4      alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
status_df = pd.read_csv("../data/status.csv", na_values="\\N")
status_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %% [markdown]
# ## Finding the Heuristic Model
#
# Let's start with the idea that, people who qualify close to the front of the grid are more likely to end up on the podium. So, what we'll do is:
# * Look at the previous race data
# * Find all the instances where that grid position ended up in a podium slot
# * We'll then get a list of probabilities for each of the positions that we can apply as a model

# %%
grid_result_df = res_df[["resultId", "raceId", "grid", "position"]].copy()
grid_result_df
# Out:
#        resultId  raceId  grid  position
# 0             1      18   1.0       1.0
# 1             2      18   5.0       2.0
# 2             3      18   7.0       3.0
# 3             4      18  11.0       4.0
# 4             5      18   3.0       5.0
# ...         ...     ...   ...       ...
# 27299     27305    1171  21.0      18.0
# 27300     27306    1171  20.0      19.0
# 27301     27307    1171  17.0      20.0
# 27302     27308    1171  22.0      21.0
# 27303     27309    1171  18.0      22.0
#
# [27304 rows x 4 columns]

# %%
grid_result_df["podium"] = grid_result_df["position"] <= 3
grid_result_df
# Out:
#        resultId  raceId  grid  position  podium
# 0             1      18   1.0       1.0    True
# 1             2      18   5.0       2.0    True
# 2             3      18   7.0       3.0    True
# 3             4      18  11.0       4.0   False
# 4             5      18   3.0       5.0   False
# ...         ...     ...   ...       ...     ...
# 27299     27305    1171  21.0      18.0   False
# 27300     27306    1171  20.0      19.0   False
# 27301     27307    1171  17.0      20.0   False
# 27302     27308    1171  22.0      21.0   False
# 27303     27309    1171  18.0      22.0   False
#
# [27304 rows x 5 columns]

# %%
pd.DataFrame(grid_result_df.groupby("grid")["podium"].mean()).reset_index()
# Out:
#     grid    podium
# 0    0.0  0.000000
# 1    1.0  0.639415
# 2    2.0  0.562989
# 3    3.0  0.465398
# 4    4.0  0.341969
# 5    5.0  0.247841
# 6    6.0  0.182450
# 7    7.0  0.127476
# 8    8.0  0.096970
# 9    9.0  0.081174
# 10  10.0  0.057093
# 11  11.0  0.038860
# 12  12.0  0.036427
# 13  13.0  0.029540
# 14  14.0  0.028796
# 15  15.0  0.014047
# 16  16.0  0.013321
# 17  17.0  0.009865
# 18  18.0  0.005576
# 19  19.0  0.005676
# 20  20.0  0.008000
# 21  21.0  0.004286
# 22  22.0  0.004552
# 23  23.0  0.004415
# 24  24.0  0.004662
# 25  25.0  0.003322
# 26  26.0  0.012097
# 27  27.0  0.000000
# 28  28.0  0.033333
# 29  29.0  0.000000
# 30  30.0  0.000000
# 31  31.0  0.000000
# 32  32.0  0.058824
# 33  33.0  0.000000
# 34  34.0  0.000000

# %% [markdown]
# We can see here that we get up to 34 positions, this is because at the moment we're training on the *full* set of data, which we probably don't want to. We'll restrict it back down to anything post 1990 up to the end of 2024 to keep it consistent

# %%
recent_grid_result_df = grid_result_df.copy()

recent_grid_result_df = pd.merge(
    left=recent_grid_result_df,
    right=race_df[["raceId", "year"]],
    on="raceId"
)

recent_grid_result_df = recent_grid_result_df[(recent_grid_result_df["year"] > 1990) & (recent_grid_result_df["year"] <= 2024)]
recent_grid_result_df
# Out:
#        resultId  raceId  grid  position  podium  year
# 0             1      18   1.0       1.0    True  2008
# 1             2      18   5.0       2.0    True  2008
# 2             3      18   7.0       3.0    True  2008
# 3             4      18  11.0       4.0   False  2008
# 4             5      18   3.0       5.0   False  2008
# ...         ...     ...   ...       ...     ...   ...
# 26754     26760    1144  14.0      16.0   False  2024
# 26755     26761    1144  12.0      17.0   False  2024
# 26756     26762    1144   9.0       NaN   False  2024
# 26757     26763    1144  20.0       NaN   False  2024
# 26758     26764    1144  10.0       NaN   False  2024
#
# [13787 rows x 6 columns]

# %%
pd.DataFrame(recent_grid_result_df.groupby("grid")["podium"].mean()).reset_index()
# Out:
#     grid    podium
# 0    0.0  0.000000
# 1    1.0  0.748800
# 2    2.0  0.630819
# 3    3.0  0.512000
# 4    4.0  0.336000
# 5    5.0  0.212800
# 6    6.0  0.166400
# 7    7.0  0.096154
# 8    8.0  0.070400
# 9    9.0  0.041600
# 10  10.0  0.046549
# 11  11.0  0.024077
# 12  12.0  0.019231
# 13  13.0  0.020833
# 14  14.0  0.017628
# 15  15.0  0.014446
# 16  16.0  0.008026
# 17  17.0  0.009569
# 18  18.0  0.004862
# 19  19.0  0.004910
# 20  20.0  0.012346
# 21  21.0  0.002985
# 22  22.0  0.006192
# 23  23.0  0.000000
# 24  24.0  0.007353
# 25  25.0  0.000000
# 26  26.0  0.000000
# 27  27.0  0.000000
# 28  28.0  0.000000

# %% [markdown]
# F12 didn't settle on 20-22 grids until about 2010, these don't really provide much utility because the signal is tiny in them anyway. Also we have position 0 as pit late starts which we can probably ignore as well

# %%
recent_grid_result_df = recent_grid_result_df[
    (recent_grid_result_df["grid"] > 0) & 
    (recent_grid_result_df["grid"] <= 22)
]

grid_podium_probabilities_df = pd.DataFrame(recent_grid_result_df.groupby("grid")["podium"].mean()).reset_index()
grid_podium_probabilities_df
# Out:
#     grid    podium
# 0    1.0  0.748800
# 1    2.0  0.630819
# 2    3.0  0.512000
# 3    4.0  0.336000
# 4    5.0  0.212800
# 5    6.0  0.166400
# 6    7.0  0.096154
# 7    8.0  0.070400
# 8    9.0  0.041600
# 9   10.0  0.046549
# 10  11.0  0.024077
# 11  12.0  0.019231
# 12  13.0  0.020833
# 13  14.0  0.017628
# 14  15.0  0.014446
# 15  16.0  0.008026
# 16  17.0  0.009569
# 17  18.0  0.004862
# 18  19.0  0.004910
# 19  20.0  0.012346
# 20  21.0  0.002985
# 21  22.0  0.006192

# %%
plt.xlabel("Grid Positoin")
plt.ylabel("Podium Probability")
plt.title("Podium Rate by Grid Position")
sns.lineplot(grid_podium_probabilities_df, x="grid", y="podium")
# Out:
# <Axes: title={'center': 'Podium Rate by Grid Position'}, xlabel='Grid Positoin', ylabel='Podium Probability'>

# %% [markdown]
# ## Choosing a Metric
#
# How do we *measure* how accurate our model is? We've got a couple of different options here:
# * F1 score is a decent option, as it balances precision and recall so we can see if we're too liberal or conservative with our labelling. The problem though is that to calculate an F1 score we need a threshold and we have to *choose* that threshold which limits our visibility. Because there are only 3 podium slots and 22 drivers now, our positive class is heavily imbalanced which makes it easy to game.
# * AUC/ROC is a little better for this reason, we can see the whole curve and how choosing particular probabilities thresholds affects the results.
# * Brier score might actually be the best because we're working with probabilities, if we had a particular probability, atleast with AUC/ROC we could be massively off in our predicted probabilities and still correct, because Brier score is the mean of the squared differences of the actual vs predicted probabilities it gives us a better picture of not only if we are correct or not, but *how* correct our probability range is. The squaring affect also means that we can heavily punish the model being overconfident on incorrect answers, and also penalisizing underconfidence as well.
#
# In summary, I think that we can and should use a combination of:
# * Brier score (Primary)
# * AUC/ROC (Secondary)
#
# The Brier score will tell us "How well are your probabilities calcuclated?" and the AUC tells us if the model is ranking drivers correctly. This gives us a nice complete picture of how well our model is doing.
#
#
# So, now for the big question. How well does our heuristic model do? We'll use 2025 as our test set:
#
# ## Evaluating the Heuristic Model
#
# ### AUC/ROC

# %%
race_result_df = pd.merge(
    left=res_df[["raceId", "resultId", "grid", "position"]],
    right=race_df[["raceId", "year"]],
    on="raceId"
)

race_result_2025_df = race_result_df[(race_result_df["year"] >= 2025) & (race_result_df["year"] <= 2025)].copy()
race_result_2025_df
# Out:
#        raceId  resultId  grid  position  year
# 26759    1145     26765   1.0       1.0  2025
# 26760    1145     26766   3.0       2.0  2025
# 26761    1145     26767   4.0       3.0  2025
# 26762    1145     26768  16.0       4.0  2025
# 26763    1145     26769   6.0       5.0  2025
# ...       ...       ...   ...       ...   ...
# 27233    1168     27239  17.0      16.0  2025
# 27234    1168     27240   9.0      17.0  2025
# 27235    1168     27241  13.0      18.0  2025
# 27236    1168     27242  19.0      19.0  2025
# 27237    1168     27243  20.0      20.0  2025
#
# [479 rows x 5 columns]

# %%
race_result_2025_df["podiumFinish"] = np.where(race_result_2025_df["position"] <= 3, 1, 0) 
race_result_2025_df
# Out:
#        raceId  resultId  grid  position  year  podiumFinish
# 26759    1145     26765   1.0       1.0  2025             1
# 26760    1145     26766   3.0       2.0  2025             1
# 26761    1145     26767   4.0       3.0  2025             1
# 26762    1145     26768  16.0       4.0  2025             0
# 26763    1145     26769   6.0       5.0  2025             0
# ...       ...       ...   ...       ...   ...           ...
# 27233    1168     27239  17.0      16.0  2025             0
# 27234    1168     27240   9.0      17.0  2025             0
# 27235    1168     27241  13.0      18.0  2025             0
# 27236    1168     27242  19.0      19.0  2025             0
# 27237    1168     27243  20.0      20.0  2025             0
#
# [479 rows x 6 columns]

# %%
race_result_2025_df = pd.merge(
    left=race_result_2025_df,
    right=grid_podium_probabilities_df,
    on="grid"
).rename(columns={"podium": "podiumProbability"})

race_result_2025_df
# Out:
#      raceId  resultId  grid  position  year  podiumFinish  podiumProbability
# 0      1145     26765   1.0       1.0  2025             1           0.748800
# 1      1145     26766   3.0       2.0  2025             1           0.512000
# 2      1145     26767   4.0       3.0  2025             1           0.336000
# 3      1145     26768  16.0       4.0  2025             0           0.008026
# 4      1145     26769   6.0       5.0  2025             0           0.166400
# ..      ...       ...   ...       ...   ...           ...                ...
# 454    1168     27239  17.0      16.0  2025             0           0.009569
# 455    1168     27240   9.0      17.0  2025             0           0.041600
# 456    1168     27241  13.0      18.0  2025             0           0.020833
# 457    1168     27242  19.0      19.0  2025             0           0.004910
# 458    1168     27243  20.0      20.0  2025             0           0.012346
#
# [459 rows x 7 columns]

# %%
# Compute the ROC curve and the AUC score.
fpr, tpr, thresholds = roc_curve(race_result_2025_df["podiumFinish"], race_result_2025_df["podiumProbability"])
auc_score = roc_auc_score(race_result_2025_df["podiumFinish"], race_result_2025_df["podiumProbability"])
auc_value = auc(fpr, tpr)

# Plot the ROC curve and show the AUC score.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Heuristic baseline ROC curve')
plt.legend()
plt.show()

# %% [markdown]
# ### Brier Score
#
# Now we move on to calculating the Brier score, we want values close to 0 as 0 would be perfectly accurate probabilities, 1 would be perfectly innacurate. We end up with 0.06 (to 2 d.p) which is remarkably good already.

# %%
brier_score_loss(race_result_2025_df["podiumFinish"], race_result_2025_df["podiumProbability"])
# Out:
# 0.0592146458315199

# %% [markdown]
# ## The Problem
#
# One of the problems that we have however, is that using the qualifying position for the race is kind of cheating. It's halfway through the race weekend and a lot of other variables get baked into those qualifying positions which make them so strong!
#
# Let's instead choose something that we know outside of the race weekend entirely. Let's go for, the last 5 races and if the driver achived a podium, and then we can apply these percentages forward for the driver.

# %%
race_results_by_year_df = pd.merge(
    left=res_df[["resultId", "raceId", "driverId", "grid", "position"]],
    right=race_df[["raceId", "year", "round"]],
    on="raceId"
).sort_values(["year", "round"])

race_results_by_year_df = pd.merge(
    left=race_results_by_year_df,
    right=drivers_df[["driverId", "forename", "surname"]],
    on="driverId"
)

race_results_by_year_df["driverName"] = race_results_by_year_df["forename"] + " " +  race_results_by_year_df["surname"]
race_results_by_year_df = race_results_by_year_df.drop(columns=["forename", "surname"])

race_results_by_year_df
# Out:
#        resultId  raceId  driverId  grid  position  year  round  \
# 0         20025     833       642   1.0       1.0  1950      1
# 1         20026     833       786   2.0       2.0  1950      1
# 2         20027     833       686   4.0       3.0  1950      1
# 3         20028     833       704   6.0       4.0  1950      1
# 4         20029     833       627   9.0       5.0  1950      1
# ...         ...     ...       ...   ...       ...   ...    ...
# 27299     27305    1171         4  21.0      18.0  2026      3
# 27300     27306    1171       822  20.0      19.0  2026      3
# 27301     27307    1171       848  17.0      20.0  2026      3
# 27302     27308    1171       840  22.0      21.0  2026      3
# 27303     27309    1171       860  18.0      22.0  2026      3
#
#             driverName
# 0          Nino Farina
# 1        Luigi Fagioli
# 2          Reg Parnell
# 3       Yves Cabantous
# 4         Louis Rosier
# ...                ...
# 27299  Fernando Alonso
# 27300  Valtteri Bottas
# 27301  Alexander Albon
# 27302     Lance Stroll
# 27303   Oliver Bearman
#
# [27304 rows x 8 columns]

# %%
race_results_by_year_df = race_results_by_year_df[
    (race_results_by_year_df["year"] > 1990) & 
    (race_results_by_year_df["year"] <= 2024)
].copy()

race_results_by_year_df
# Out:
#        resultId  raceId  driverId  grid  position  year  round  \
# 12972      6473     305       102   1.0       1.0  1991      1
# 12973      6474     305       117   2.0       2.0  1991      1
# 12974      6475     305       137   5.0       3.0  1991      1
# 12975      6476     305       131  11.0       4.0  1991      1
# 12976      6477     305       138  16.0       5.0  1991      1
# ...         ...     ...       ...   ...       ...   ...    ...
# 26754     26760    1144       825  14.0      16.0  2024     24
# 26755     26761    1144       859  12.0      17.0  2024     24
# 26756     26762    1144       822   9.0       NaN  2024     24
# 26757     26763    1144       861  20.0       NaN  2024     24
# 26758     26764    1144       815  10.0       NaN  2024     24
#
#              driverName
# 12972      Ayrton Senna
# 12973       Alain Prost
# 12974     Nelson Piquet
# 12975    Stefano Modena
# 12976   Satoru Nakajima
# ...                 ...
# 26754   Kevin Magnussen
# 26755       Liam Lawson
# 26756   Valtteri Bottas
# 26757  Franco Colapinto
# 26758      Sergio Pérez
#
# [13787 rows x 8 columns]

# %% [markdown]
# What we do here is calculate the rolling mean for the drivers based on the *previous* 5 races, the shift is so that we don't take into account the current race. We set up a podium column first that we can use as a binary field later for ease

# %%
race_results_by_year_df["podium"] = race_results_by_year_df["position"] <= 3

race_results_by_year_df["driver_podium_rate_5"] = (
    race_results_by_year_df.groupby("driverId")["podium"]
    .transform(lambda x: x.shift(1).rolling(5, min_periods=1).mean())
)

race_results_by_year_df.tail()
# Out:
#        resultId  raceId  driverId  grid  position  year  round  \
# 26754     26760    1144       825  14.0      16.0  2024     24
# 26755     26761    1144       859  12.0      17.0  2024     24
# 26756     26762    1144       822   9.0       NaN  2024     24
# 26757     26763    1144       861  20.0       NaN  2024     24
# 26758     26764    1144       815  10.0       NaN  2024     24
#
#              driverName  podium  driver_podium_rate_5
# 26754   Kevin Magnussen   False                   0.0
# 26755       Liam Lawson   False                   0.0
# 26756   Valtteri Bottas   False                   0.0
# 26757  Franco Colapinto   False                   0.0
# 26758      Sergio Pérez   False                   0.0

# %% [markdown]
# For drivers with less than 5 races, we'll just fill them with a 0 for podium rate

# %%
race_results_by_year_df["driver_podium_rate_5"] = race_results_by_year_df["driver_podium_rate_5"].fillna(0)

# %%
driver_current_form = (
    race_results_by_year_df.groupby("driverId")[["driver_podium_rate_5", "driverName", "year"]]
    .last()
    .reset_index()
)

driver_current_form
# Out:
#      driverId  driver_podium_rate_5         driverName  year
# 0           1                   0.2     Lewis Hamilton  2024
# 1           2                   0.0      Nick Heidfeld  2011
# 2           3                   1.0       Nico Rosberg  2016
# 3           4                   0.0    Fernando Alonso  2024
# 4           5                   0.0  Heikki Kovalainen  2013
# ..        ...                   ...                ...   ...
# 196       858                   0.0     Logan Sargeant  2024
# 197       859                   0.0        Liam Lawson  2024
# 198       860                   0.0     Oliver Bearman  2024
# 199       861                   0.0   Franco Colapinto  2024
# 200       862                   0.0        Jack Doohan  2024
#
# [201 rows x 4 columns]

# %% [markdown]
# ## Recalculating the Stats
#
# We do a left join on the results so we get the years of the races, and then filter it down to only the 2025 races that we want to predict, we add back in the binary podium finish feature based on a driver finishing in the top 3 positions.
#
# Finally, we do a left join on this based on the drivers current form data that we calculated from the 2024 and backwards dataset, we will the podium rate with 0 for those that do not have atleast 5 races under their belt which covers the rookies. This feels fair because we don't have high expectations for rookies anyway.

# %%
race_result_updated_2025_df = pd.merge(
    res_df[["raceId", "driverId", "position"]],
    race_df[["raceId", "year"]],
    on="raceId"
)

race_result_updated_2025_df = race_result_updated_2025_df[race_result_updated_2025_df["year"] == 2025].copy()
race_result_updated_2025_df["podiumFinish"] = (race_result_updated_2025_df["position"] <= 3).astype(int)

race_result_updated_2025_df = pd.merge(
    race_result_updated_2025_df,
    driver_current_form[["driverId", "driver_podium_rate_5"]],
    on="driverId",
    how="left"
).fillna({"driver_podium_rate_5": 0})

race_result_updated_2025_df
# Out:
#      raceId  driverId  position  year  podiumFinish  driver_podium_rate_5
# 0      1145       846       1.0  2025             1                   0.2
# 1      1145       830       2.0  2025             1                   0.6
# 2      1145       847       3.0  2025             1                   0.2
# 3      1145       863       4.0  2025             0                   0.0
# 4      1145       848       5.0  2025             0                   0.0
# ..      ...       ...       ...   ...           ...                   ...
# 474    1168       848      16.0  2025             0                   0.0
# 475    1168       865      17.0  2025             0                   0.0
# 476    1168       859      18.0  2025             0                   0.0
# 477    1168       842      19.0  2025             0                   0.2
# 478    1168       861      20.0  2025             0                   0.0
#
# [479 rows x 6 columns]

# %%
# Compute the ROC curve and the AUC score.
fpr, tpr, thresholds = roc_curve(race_result_updated_2025_df["podiumFinish"], race_result_updated_2025_df["driver_podium_rate_5"])
auc_score = roc_auc_score(race_result_updated_2025_df["podiumFinish"], race_result_updated_2025_df["driver_podium_rate_5"])
auc_value = auc(fpr, tpr)

# Plot the ROC curve and show the AUC score.
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Rolling podium rate baseline ROC curve')
plt.legend()
plt.show()

# %%
brier_score_loss(race_result_updated_2025_df["podiumFinish"], race_result_updated_2025_df["driver_podium_rate_5"])
# Out:
# 0.12041753653444678

# %% [markdown]
# ## Summary
#
# In summary, with the updated metrics we get the following scores:
# * 0.79 AUC
# * 0.12 Brier Score
#
# We can see that this is a pretty signicant drop from 0.93 AUC and 0.06 Brier score from before, but this was to be expected as we are no longer baking in a lot of additional information that was available right before the real race such as, how the driver is doing, how the car is doing, a lot of familiarity and expectations of the track have already been set. So, we've got a tough yes, but not impossible metric to beat with our base ML model!
